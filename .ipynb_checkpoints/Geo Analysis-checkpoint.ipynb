# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import math
sb.set()
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import precision_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
clvdata = pd.read_csv("CLVsummary.csv")
clvdata.drop(columns = clvdata.columns[0], inplace = True)
clvdata
# Out:
#                     customer_unique_id  frequency  recency      T  \
# 0     004288347e5e88a27ded2bb23747066c        1.0    171.0  397.0
# 1     00a39521eb40f7012db50455bf083460        1.0     11.0   97.0
# 2     011575986092c30523ecb71ff10cb473        1.0     60.0  192.0
# 3     011b4adcd54683b480c4d841250a987f        1.0    177.0  371.0
# 4     012452d40dafae4df401bced74cdb490        1.0    330.0  436.0
# ...                                ...        ...      ...    ...
# 2010  fe81bb32c243a86b2f86fbf053fe6140        4.0    242.0  310.0
# 2011  fed519569d16e690df6f89cb99d4e682        1.0     88.0  251.0
# 2012  ff03923ad1eb9e32304deb7f9b2a45c9        1.0     33.0  127.0
# 2013  ff8892f7c26aa0446da53d01b18df463        1.0    186.0  461.0
# 2014  ff922bdd6bafcdf99cb90d7f39cea5b3        2.0    204.0  552.0
#
#       monetary_value  probability_alive  pred_num_txn  exp_avg_sales  \
# 0             87.900           0.042640          0.00      95.618031
# 1             11.550           0.053582          0.01      19.144075
# 2             63.900           0.047191          0.01      71.579066
# 3            227.880           0.048872          0.01     235.825290
# 4           1320.000           0.082800          0.01    1329.718362
# ...              ...                ...           ...            ...
# 2010         369.850           0.407697          0.13     371.891459
# 2011          89.900           0.043916          0.01      97.621278
# 2012         220.640           0.054838          0.01     228.573536
# 2013          99.900           0.037292          0.00     107.637513
# 2014          34.945           0.067314          0.01      38.757934
#
#       predicted_clv  manual_predicted_clv  clv_profit
# 0          0.448267              0.000000    0.044827
# 1          0.231999              0.191441    0.023200
# 2          0.572376              0.715791    0.057238
# 3          1.326227              2.358253    0.132623
# 4         11.347272             13.297184    1.134727
# ...             ...                   ...         ...
# 2010      46.676690             48.345890    4.667669
# 2011       0.628549              0.976213    0.062855
# 2012       2.563879              2.285735    0.256388
# 2013       0.397728              0.000000    0.039773
# 2014       0.331310              0.387579    0.033131
#
# [2015 rows x 11 columns]

# %%
geodata = pd.read_csv("olist_geolocation_dataset.csv")
geodata.rename(columns={"geolocation_zip_code_prefix": "customer_zip_code_prefix"}, inplace = True)
geodata
# Out:
#          customer_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                            1037       -23.545621       -46.639292
# 1                            1046       -23.546081       -46.644820
# 2                            1046       -23.546129       -46.642951
# 3                            1041       -23.544392       -46.639499
# 4                            1035       -23.541578       -46.641607
# ...                           ...              ...              ...
# 1000158                     99950       -28.068639       -52.010705
# 1000159                     99900       -27.877125       -52.224882
# 1000160                     99950       -28.071855       -52.014716
# 1000161                     99980       -28.388932       -51.846871
# 1000162                     99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# 1              sao paulo                SP
# 2              sao paulo                SP
# 3              sao paulo                SP
# 4              sao paulo                SP
# ...                  ...               ...
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS
#
# [1000163 rows x 5 columns]

# %%
customerdata = pd.read_csv("olist_customers_dataset.csv")
customerdata.drop(columns = 'customer_id', inplace = True)
customerdata
# Out:
#                      customer_unique_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# 4      345ecd01c38d18a9036ed96c73b8d066                     13056
# ...                                 ...                       ...
# 99436  1a29b476fee25c95fbafc67c5ac95cf8                      3937
# 99437  d52a67c98be1cf6a5c84435bd38d095d                      6764
# 99438  e9f50caf99f032f0bf3c55141f019d99                     60115
# 99439  73c2643a0a458b49f58cea58833b192e                     92120
# 99440  84732c5050c01db9b23e19ba39899398                      6703
#
#                customer_city customer_state
# 0                     franca             SP
# 1      sao bernardo do campo             SP
# 2                  sao paulo             SP
# 3            mogi das cruzes             SP
# 4                   campinas             SP
# ...                      ...            ...
# 99436              sao paulo             SP
# 99437        taboao da serra             SP
# 99438              fortaleza             CE
# 99439                 canoas             RS
# 99440                  cotia             SP
#
# [99441 rows x 4 columns]

# %%
new = pd.merge(customerdata, clvdata, on='customer_unique_id')
new
# Out:
#                     customer_unique_id  customer_zip_code_prefix  \
# 0     4c93744516667ad3b8f1fb645a3116a4                     89254
# 1     4c93744516667ad3b8f1fb645a3116a4                     89253
# 2     295c05e81917928d76245e842748184d                      5704
# 3     295c05e81917928d76245e842748184d                      5704
# 4     e9dd12dca17352644a959d9dea133935                     42800
# ...                                ...                       ...
# 4337  88fcb680dc8cd2e540010c0750b78242                     13348
# 4338  2dcbfb99d95c7ba6eb992a98627f45b8                      4890
# 4339  2dcbfb99d95c7ba6eb992a98627f45b8                      4890
# 4340  da29b8a3970adddb9ed2dc8a492065af                     29027
# 4341  da29b8a3970adddb9ed2dc8a492065af                     29027
#
#        customer_city customer_state  frequency  recency      T  \
# 0     jaragua do sul             SC        1.0     31.0  348.0
# 1     jaragua do sul             SC        1.0     31.0  348.0
# 2          sao paulo             SP        1.0     91.0  174.0
# 3          sao paulo             SP        1.0     91.0  174.0
# 4           camacari             BA        1.0     44.0  176.0
# ...              ...            ...        ...      ...    ...
# 4337      indaiatuba             SP        1.0    270.0  491.0
# 4338       sao paulo             SP        1.0      5.0  273.0
# 4339       sao paulo             SP        1.0      5.0  273.0
# 4340         vitoria             ES        1.0     90.0  434.0
# 4341         vitoria             ES        1.0     90.0  434.0
#
#       monetary_value  probability_alive  pred_num_txn  exp_avg_sales  \
# 0             246.62           0.016102          0.00     254.595715
# 1             246.62           0.016102          0.00     254.595715
# 2             220.98           0.068963          0.01     228.914088
# 3             220.98           0.068963          0.01     228.914088
# 4              44.99           0.044398          0.01      52.638366
# ...              ...                ...           ...            ...
# 4337           56.50           0.053132          0.01      64.167052
# 4338           85.99           0.016522          0.00      93.704930
# 4339           85.99           0.016522          0.00      93.704930
# 4340           19.90           0.020568          0.00      27.507632
# 4341           19.90           0.020568          0.00      27.507632
#
#       predicted_clv  manual_predicted_clv  clv_profit
# 0          0.492039              0.000000    0.049204
# 1          0.492039              0.000000    0.049204
# 2          2.808446              2.289141    0.280845
# 3          2.808446              2.289141    0.280845
# 4          0.413468              0.526384    0.041347
# ...             ...                   ...         ...
# 4337       0.322859              0.641671    0.032286
# 4338       0.216120              0.000000    0.021612
# 4339       0.216120              0.000000    0.021612
# 4340       0.058498              0.000000    0.005850
# 4341       0.058498              0.000000    0.005850
#
# [4342 rows x 14 columns]

# %%
len(new.customer_unique_id.unique())
# Out:
# 2015

# %%
new1 = new.drop_duplicates(subset=['customer_unique_id'])
new1 = new1.sort_values(by = 'customer_unique_id')
new1 = new1.reset_index()
new1 = new1.drop(columns = 'index')
new1
# Out:
#                     customer_unique_id  customer_zip_code_prefix  \
# 0     004288347e5e88a27ded2bb23747066c                     26220
# 1     00a39521eb40f7012db50455bf083460                     72595
# 2     011575986092c30523ecb71ff10cb473                     30660
# 3     011b4adcd54683b480c4d841250a987f                     44200
# 4     012452d40dafae4df401bced74cdb490                      3220
# ...                                ...                       ...
# 2010  fe81bb32c243a86b2f86fbf053fe6140                      1453
# 2011  fed519569d16e690df6f89cb99d4e682                     20540
# 2012  ff03923ad1eb9e32304deb7f9b2a45c9                     18703
# 2013  ff8892f7c26aa0446da53d01b18df463                     45972
# 2014  ff922bdd6bafcdf99cb90d7f39cea5b3                     17340
#
#        customer_city customer_state  frequency  recency      T  \
# 0        nova iguacu             RJ        1.0    171.0  397.0
# 1           brasilia             DF        1.0     11.0   97.0
# 2     belo horizonte             MG        1.0     60.0  192.0
# 3        santo amaro             BA        1.0    177.0  371.0
# 4          sao paulo             SP        1.0    330.0  436.0
# ...              ...            ...        ...      ...    ...
# 2010       sao paulo             SP        4.0    242.0  310.0
# 2011  rio de janeiro             RJ        1.0     88.0  251.0
# 2012           avare             SP        1.0     33.0  127.0
# 2013         ibiraja             BA        1.0    186.0  461.0
# 2014    barra bonita             SP        2.0    204.0  552.0
#
#       monetary_value  probability_alive  pred_num_txn  exp_avg_sales  \
# 0             87.900           0.042640          0.00      95.618031
# 1             11.550           0.053582          0.01      19.144075
# 2             63.900           0.047191          0.01      71.579066
# 3            227.880           0.048872          0.01     235.825290
# 4           1320.000           0.082800          0.01    1329.718362
# ...              ...                ...           ...            ...
# 2010         369.850           0.407697          0.13     371.891459
# 2011          89.900           0.043916          0.01      97.621278
# 2012         220.640           0.054838          0.01     228.573536
# 2013          99.900           0.037292          0.00     107.637513
# 2014          34.945           0.067314          0.01      38.757934
#
#       predicted_clv  manual_predicted_clv  clv_profit
# 0          0.448267              0.000000    0.044827
# 1          0.231999              0.191441    0.023200
# 2          0.572376              0.715791    0.057238
# 3          1.326227              2.358253    0.132623
# 4         11.347272             13.297184    1.134727
# ...             ...                   ...         ...
# 2010      46.676690             48.345890    4.667669
# 2011       0.628549              0.976213    0.062855
# 2012       2.563879              2.285735    0.256388
# 2013       0.397728              0.000000    0.039773
# 2014       0.331310              0.387579    0.033131
#
# [2015 rows x 14 columns]

# %%
new2 = new1[['customer_unique_id','customer_zip_code_prefix','customer_city','customer_state','predicted_clv']]
new2
# Out:
#                     customer_unique_id  customer_zip_code_prefix  \
# 0     004288347e5e88a27ded2bb23747066c                     26220
# 1     00a39521eb40f7012db50455bf083460                     72595
# 2     011575986092c30523ecb71ff10cb473                     30660
# 3     011b4adcd54683b480c4d841250a987f                     44200
# 4     012452d40dafae4df401bced74cdb490                      3220
# ...                                ...                       ...
# 2010  fe81bb32c243a86b2f86fbf053fe6140                      1453
# 2011  fed519569d16e690df6f89cb99d4e682                     20540
# 2012  ff03923ad1eb9e32304deb7f9b2a45c9                     18703
# 2013  ff8892f7c26aa0446da53d01b18df463                     45972
# 2014  ff922bdd6bafcdf99cb90d7f39cea5b3                     17340
#
#        customer_city customer_state  predicted_clv
# 0        nova iguacu             RJ       0.448267
# 1           brasilia             DF       0.231999
# 2     belo horizonte             MG       0.572376
# 3        santo amaro             BA       1.326227
# 4          sao paulo             SP      11.347272
# ...              ...            ...            ...
# 2010       sao paulo             SP      46.676690
# 2011  rio de janeiro             RJ       0.628549
# 2012           avare             SP       2.563879
# 2013         ibiraja             BA       0.397728
# 2014    barra bonita             SP       0.331310
#
# [2015 rows x 5 columns]

# %%
new3 = pd.merge(geodata, new2, on='customer_zip_code_prefix')
new3
# Out:
#         customer_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                           1046       -23.546081       -46.644820
# 1                           1046       -23.546129       -46.642951
# 2                           1046       -23.546081       -46.644820
# 3                           1046       -23.545884       -46.643163
# 4                           1046       -23.545166       -46.643786
# ...                          ...              ...              ...
# 324067                     99750       -27.394038       -52.568970
# 324068                     99750       -27.394458       -52.570787
# 324069                     99750       -27.394458       -52.570787
# 324070                     99750       -27.396426       -52.567746
# 324071                     99750       -27.390595       -52.569643
#
#        geolocation_city geolocation_state                customer_unique_id  \
# 0             sao paulo                SP  6f8e7d40046694539c87b98cb5096a28
# 1             sao paulo                SP  6f8e7d40046694539c87b98cb5096a28
# 2             sao paulo                SP  6f8e7d40046694539c87b98cb5096a28
# 3             sao paulo                SP  6f8e7d40046694539c87b98cb5096a28
# 4             sao paulo                SP  6f8e7d40046694539c87b98cb5096a28
# ...                 ...               ...                               ...
# 324067     erval grande                RS  124ef8d5acc80858c69d34e3e08b572d
# 324068     erval grande                RS  124ef8d5acc80858c69d34e3e08b572d
# 324069     erval grande                RS  124ef8d5acc80858c69d34e3e08b572d
# 324070     erval grande                RS  124ef8d5acc80858c69d34e3e08b572d
# 324071     erval grande                RS  124ef8d5acc80858c69d34e3e08b572d
#
#        customer_city customer_state  predicted_clv
# 0          sao paulo             SP       0.404963
# 1          sao paulo             SP       0.404963
# 2          sao paulo             SP       0.404963
# 3          sao paulo             SP       0.404963
# 4          sao paulo             SP       0.404963
# ...              ...            ...            ...
# 324067  erval grande             RS       4.489285
# 324068  erval grande             RS       4.489285
# 324069  erval grande             RS       4.489285
# 324070  erval grande             RS       4.489285
# 324071  erval grande             RS       4.489285
#
# [324072 rows x 9 columns]

# %% [markdown]
# # Many duplicates as we are unable to derive customer's exact address. So we will just drop all the duplicates as the exact locations of each duplicate is quite near each other.

# %%
new4 = new3.drop_duplicates(subset=['customer_unique_id'])
new4 = new4.sort_values(by = 'customer_unique_id')
new4 = new4.reset_index()
new4 = new4.drop(columns = 'index')
new4
# Out:
#       customer_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                        26220       -22.758886       -43.435672
# 1                        30660       -19.983999       -44.032573
# 2                        44200       -12.548775       -38.712588
# 3                         3220       -23.590818       -46.551266
# 4                         6550       -23.414784       -46.974449
# ...                        ...              ...              ...
# 2003                      1453       -23.583436       -46.686463
# 2004                     20540       -22.921733       -43.258689
# 2005                     18703       -23.122708       -48.921441
# 2006                     45972       -17.197929       -40.220196
# 2007                     17340       -22.486086       -48.547450
#
#            geolocation_city geolocation_state  \
# 0               nova iguacu                RJ
# 1            belo horizonte                MG
# 2               santo amaro                BA
# 3                 sao paulo                SP
# 4     pirapora do bom jesus                SP
# ...                     ...               ...
# 2003              sao paulo                SP
# 2004         rio de janeiro                RJ
# 2005                  avare                SP
# 2006                ibirajá                BA
# 2007           barra bonita                SP
#
#                     customer_unique_id          customer_city customer_state  \
# 0     004288347e5e88a27ded2bb23747066c            nova iguacu             RJ
# 1     011575986092c30523ecb71ff10cb473         belo horizonte             MG
# 2     011b4adcd54683b480c4d841250a987f            santo amaro             BA
# 3     012452d40dafae4df401bced74cdb490              sao paulo             SP
# 4     012a218df8995d3ec3bb221828360c86  pirapora do bom jesus             SP
# ...                                ...                    ...            ...
# 2003  fe81bb32c243a86b2f86fbf053fe6140              sao paulo             SP
# 2004  fed519569d16e690df6f89cb99d4e682         rio de janeiro             RJ
# 2005  ff03923ad1eb9e32304deb7f9b2a45c9                  avare             SP
# 2006  ff8892f7c26aa0446da53d01b18df463                ibiraja             BA
# 2007  ff922bdd6bafcdf99cb90d7f39cea5b3           barra bonita             SP
#
#       predicted_clv
# 0          0.448267
# 1          0.572376
# 2          1.326227
# 3         11.347272
# 4         19.711841
# ...             ...
# 2003      46.676690
# 2004       0.628549
# 2005       2.563879
# 2006       0.397728
# 2007       0.331310
#
# [2008 rows x 9 columns]

# %% [markdown]
# # Now we have the locations of each customer as well as their corresponding CLV.
#
# # We can now find out which regions in Brazil generate more profit for Olist, so that Olist's marketing and sales team can concentrate on those areas
